# %%
pip install ultralytics

from ultralytics import YOLO
model = YOLO("yolov8m.pt")

# %%writefile data.yaml

train: /content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-train/images
val: /content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-val/images

nc: 10

names:
  0: pedestrian
  1: people
  2: bicycle
  3: car
  4: van
  5: truck
  6: tricycle
  7: awning-tricycle
  8: bus
  9: motor
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# %%writefile data.yaml
#
# train: /content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-train/images
# val: /content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-val/images
#
# nc: 10
#
# names:
#   0: pedestrian
#   1: people
#   2: bicycle
#   3: car
#   4: van
#   5: truck
#   6: tricycle
#   7: awning-tricycle
#   8: bus
#   9: motor
# Out:
# Writing data.yaml

# %%
import os

path = "/content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-test-dev"

print(os.listdir(path))
# Out:
# ['images', 'labels', 'annotations']

# %%
model.train(
    data="data.yaml",

    # TRAINING
    epochs=100,
    patience=20,
    batch=8,

    # IMAGE SIZE
    imgsz=640,

    # OPTIMIZATION
    lr0=0.001,
    weight_decay=0.0005,

    # AUGMENTATION
    degrees=5,
    translate=0.1,
    scale=0.3,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.1,

    # PERFORMANCE
    cache=False,
    workers=2,
    amp=True,

    # SAVE
    project="/content/drive/MyDrive/ObjectDetection",
    name="visdrone_yolov8m"
)
# Out:
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
result = model.predict(
    source = "/content/drive/MyDrive/Datasets/vision/VisDrone/VisDrone2019-DET-val/images/0000001_02999_d_0000005.jpg",
    conf = 0.7,
    save = True
)

# %%
model = YOLO(
    "/content/drive/MyDrive/ObjectDetection/visdrone_detector-100/weights/best.pt"
)

# %%
results = model.predict(
    source="video.mp4",
    conf=0.8,
    save=True
)

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

video_path = "/content/drive/MyDrive/Datasets/test video.mp4"

cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

output_path = "/content/output_detection.mp4"

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)

# Process video frame-by-frame
while cap.isOpened():

    ret, frame = cap.read()

    if not ret:
        break


    results = model(frame)

    # Draw detections on frame
    annotated_frame = results[0].plot()

    # Write frame to output video
    out.write(annotated_frame)

    # Show frame in Colab
    cv2_imshow(annotated_frame)

    # Press q to stop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()

print("Video saved at:")
print(output_path)
